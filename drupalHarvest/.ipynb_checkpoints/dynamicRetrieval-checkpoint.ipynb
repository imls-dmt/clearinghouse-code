# %% [markdown]
# # Retrieval script for pulling data out of the testing or production ESIP Data Management Training Clearinghouse
#
# API Documentation: [https://docs.google.com/document/d/15czKFzgWNw2f-nQRZ9mMU3Elh2eETb2eBKx2XNvRGcE/edit](https://docs.google.com/document/d/15czKFzgWNw2f-nQRZ9mMU3Elh2eETb2eBKx2XNvRGcE/edit)

# %%
import json
from sys import exit
import requests
import getpass
import pandas as pd
from bs4 import BeautifulSoup
import pickle

# %%
def getIDs():
    """Returns data from either the testing or production Data Management Training Clearinghouse system as a JSON string. 
    
    Keyword arguments:
    testing     -- True (default) | False value that toggles the function between testing and production modes. If testing the request will be sent to the testing server with default credentials. If not testing the request will be sent to the production server and the user will be asked to provide a username and password when executing the function. 
    """
    
    print("========= authentication =========")
    base_url: str = 'http://dmtclearinghouse.esipfed.org/api/dmt/search'
    login_data = {
        'username': getpass.getpass("Enter your username - the input will be hidden"),
        'password': getpass.getpass("Enger your password - the input will be hidden")}
    print("==================================\n\n")
    
    
    headerString = {'Content-type': 'application/json'}
    
    r = requests.post(url = base_url+ '/user/login', headers = headerString, data = json.dumps(login_data) )
    
    #print('loginStatusCode: '+str(r.status_code))

    #print('loginText: \n'+r.text)
    #print('loginCookies: \n'+str(r.cookies) )

    cookieObj=r.cookies
    #print()
    
    r = requests.post(url = base_url+ '/user/token.json', cookies=cookieObj, headers = headerString, data = json.dumps(login_data) )
    #print( 'tokenStatusCode" '+str(r.status_code))

    #print( 'tokenText" '+r.text)

    tokenTxt=r.text.replace('{','').replace('}','').replace("token",'').replace('"','').replace(':','')
    #print( 'cleanedUpToken: '+tokenTxt)
    #print()
    
    #headerString = {'X-CSRF-TOKEN' : tokenTxt}

    get_query = requests.get(base_url+'/search_api/search_index_dmt_clearinghouse.json', cookies=cookieObj, headers = headerString)
    #print( 'getQueryStatusCode: '+str(get_query.status_code) )
    #print()

    #print( 'getQueryText: \n'+get_query.text)
    #print()
    
    return(json.loads(get_query.text)['result'].keys())

def getData(queryString='', testing=True):
    """Returns data from either the testing or production Data Management Training Clearinghouse system as a JSON string. 
    
    Keyword arguments:
    queryString -- the query string that should be appended to the base request URL. Defaults to ''
    testing     -- True (default) | False value that toggles the function between testing and production modes. If testing the request will be sent to the testing server with default credentials. If not testing the request will be sent to the production server and the user will be asked to provide a username and password when executing the function. 
    """
    
    print("========= authentication =========")
    if testing:
        base_url: str = 'http://test.dmtclearinghouse.esipfed.bluedotapps.org/api/dmt/search'
        login_data = {
            'username': 'api.persona',
            'password': 'api.persona'}
    else:
        base_url: str = 'http://dmtclearinghouse.esipfed.org/api/dmt/search'
        login_data = {
            'username': getpass.getpass("Enter your username - the input will be hidden"),
            'password': getpass.getpass("Enger your password - the input will be hidden")}
    print("==================================\n\n")
    
    
    headerString = {'Content-type': 'application/json'}
    
    r = requests.post(url = base_url+ '/user/login', headers = headerString, data = json.dumps(login_data) )
    
    #print('loginStatusCode: '+str(r.status_code))

    #print('loginText: \n'+r.text)
    #print('loginCookies: \n'+str(r.cookies) )

    cookieObj=r.cookies
    #print()
    
    r = requests.post(url = base_url+ '/user/token.json', cookies=cookieObj, headers = headerString, data = json.dumps(login_data) )
    #print( 'tokenStatusCode" '+str(r.status_code))

    #print( 'tokenText" '+r.text)

    tokenTxt=r.text.replace('{','').replace('}','').replace("token",'').replace('"','').replace(':','')
    #print( 'cleanedUpToken: '+tokenTxt)
    #print()
    
    #headerString = {'X-CSRF-TOKEN' : tokenTxt}

    get_query = requests.get(base_url+'/search_api/search_index_dmt_clearinghouse.json'+queryString, cookies=cookieObj, headers = headerString)
    #print( 'getQueryStatusCode: '+str(get_query.status_code) )
    #print()

    #print( 'getQueryText: \n'+get_query.text)
    #print()
    
    return(json.loads(get_query.text))

def json2list(dmtc_json):
    json_sub = dmtc_json['result']
    results = []
    #print(json_sub)
    for item in json_sub.values():
        result_dict = {}
        result_dict['id'] = item['id']
        print(item['id'])
        
        fields = item['fields']
        print(fields,"\n-----------\n")
        for key, value in fields.items():
            if isinstance(value, dict):
                print(key,": dvalue ",value['und'])
            elif isinstance(value, list):
                print(key,": lvalue",value)
                result_dict['key'] = value
            else:
                print(key,":",value)
            
        #frames.append(pd.DataFrame.from_dict(result_dict, orient="columns"))
        results.append(result_dict)
        
        #print(result_dict)
        #print(item)
        print("\n==========================\n")
    
    
    # result_df = pd.concat(frames)
    return(results)
    
def scrapeDMTC(testing:True):
    # Web Scraping approach to pulling values from core nodes and associated reference tables. 
    baseURL = "http://dmtclearinghouse.esipfed.org/node/"
    fields = [
        "field-name-title",
        "field-name-field-lr-url",
        "field-name-field-lr-abstract",
        "field-name-field-lr-author-people",
        "field-name-field-lr-license",
        "field-name-field-lr-usage-rights",
        "field-name-field-lr-payment-required",
        "field-name-field-lr-citation",
        "field-name-field-lr-language-primary",
        "field-name-field-lr-languages-secondary",
        "field-name-field-lr-keywords",
        "field-name-field-lr-subject",
        "field-name-field-lr-date-published",
        "field-name-field-lr-locator-id",
        "field-name-field-lr-locator-type",
        "field-name-field-lr-publisher",
        "field-name-field-lr-version",
        "field-name-field-lr-media-type",
        "field-name-field-lr-contributor-people",
        "field-name-field-lr-contributor-orgs",
        "field-name-field-lr-contact-people",
        "field-name-field-lr-contact-organizations",
        "field-name-field-lr-ed-purpose",
        "field-name-field-lr-type",
        "field-name-field-lr-ed-audience",
        "field-name-field-lr-completion-time",
        "field-name-field-lr-ed-framework",
        "field-name-field-lr-ed-framework-node-esip",
        "field-name-field-lr-ed-framework-node-usgs",
        "field-name-field-lr-ed-framework-node-data1",
        "field-name-field-lr-framework-node-fair",
        "field-name-field-dmt-submitter-name",
        "field-name-field-submission-contact-email-a",
        "field-name-field-lr-access-features"
    ]
    testCount = 5
    i = 0
    results = []
    for nodeID in getIDs():
        node2get = baseURL+nodeID
        if testing and i > testCount:
            print("skipping: ", node2get)
        else:
            print("processing: ", node2get)
            r = requests.get(node2get)
            soup = BeautifulSoup(r.text)
            result = {}
            result['id'] = nodeID
            for field in fields:
                content = []
                try:
                    if field == "field-name-title":
                        content = [soup.find("div", class_=field).get_text()]
                    elif field == "field-name-field-lr-url":
                        links = soup.find("div", class_="field-name-field-lr-url").find_all("a")
                        for link in links:
                            content.append(link.get_text())
                    elif field == "field-name-field-lr-date-published":
                        items = soup.find_all("span", class_="date-display-single")
                        for item in items:
                            content.append(item['content'])
                    elif field == "field-name-field-lr-contributor-people":
                        items = soup.find("div", class_=field).find_all("div", class_="field-item")
                        for item in items:
                            nameItems = item.find_all("div", class_="field-item")
                            nameList = []
                            for nameItem in nameItems:
                                nameList.append(nameItem.get_text())
                            if len(nameList) > 0:
                                content.append(nameList)
                    else:
                        items = soup.find("div", class_=field).find_all("div", class_="field-item")
                        for item in items:
                            content.append(item.get_text())
                    
                except:
                    content = None
                print()
                print(field,": ", content)
                result[field] = content
            #print(result)
            results.append(result)
            
        print()
        print("======================")
        i += 1
    return(results)

# %%
parameterList = [
    "field_dmt_submitter_name",
    "field_submission_contact_email_a",
    "field_lr_usage_rights",
    "field_lr_languages_secondary",
    "field_lr_contributor_orgs",
    "field_lr_access_features"
]
parameters = "?fields[]="+"&fields[]=".join(parameterList)
print(parameters)
#getResult = getData(testing=False, queryString = parameters)

print()
suppResults = json2list(getData(testing=False, queryString = parameters))
scrapeRusults = scrapeDMTC(testing=False)
# Out:
# ?fields[]=field_dmt_submitter_name&fields[]=field_submission_contact_email_a&fields[]=field_lr_usage_rights&fields[]=field_lr_languages_secondary&fields[]=field_lr_contributor_orgs&fields[]=field_lr_access_features
#
# ========= authentication =========
# Enter your username - the input will be hidden········
# Enger your password - the input will be hidden········
# ==================================
#
#
# 9410
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9412
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9413
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9415
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '125'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '125'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9570
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9571
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9572
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9573
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9574
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9576
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9577
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9578
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9579
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9584
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9585
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9586
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9587
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9588
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Nancy Hoebelheinrich', 'format': None, 'safe_value': 'Nancy Hoebelheinrich'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'nhoebel@kmotifs.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Nancy Hoebelheinrich', 'format': None, 'safe_value': 'Nancy Hoebelheinrich'}]
# field_submission_contact_email_a : dvalue  [{'email': 'nhoebel@kmotifs.com'}]
#
# ==========================
#
# 9589
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9590
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9591
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9592
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9593
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '324'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Nancy J.  Hoebelheinrich', 'format': None, 'safe_value': 'Nancy J.  Hoebelheinrich'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'nhoebel@kmotifs.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '324'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Nancy J.  Hoebelheinrich', 'format': None, 'safe_value': 'Nancy J.  Hoebelheinrich'}]
# field_submission_contact_email_a : dvalue  [{'email': 'nhoebel@kmotifs.com'}]
#
# ==========================
#
# 9594
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9595
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9596
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9597
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9598
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '321'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Nancy J.  Hoebelheinrich', 'format': None, 'safe_value': 'Nancy J.  Hoebelheinrich'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'nhoebel@kmotifs.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '321'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Nancy J.  Hoebelheinrich', 'format': None, 'safe_value': 'Nancy J.  Hoebelheinrich'}]
# field_submission_contact_email_a : dvalue  [{'email': 'nhoebel@kmotifs.com'}]
#
# ==========================
#
# 9599
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9600
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '320'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Nancy J.  Hoebelheinrich', 'format': None, 'safe_value': 'Nancy J.  Hoebelheinrich'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'nhoebel@kmotifs.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '320'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Nancy J.  Hoebelheinrich', 'format': None, 'safe_value': 'Nancy J.  Hoebelheinrich'}]
# field_submission_contact_email_a : dvalue  [{'email': 'nhoebel@kmotifs.com'}]
#
# ==========================
#
# 9601
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '325'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Nancy J.  Hoebelheinrich', 'format': None, 'safe_value': 'Nancy J.  Hoebelheinrich'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'nhoebel@kmotifs.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '325'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Nancy J.  Hoebelheinrich', 'format': None, 'safe_value': 'Nancy J.  Hoebelheinrich'}]
# field_submission_contact_email_a : dvalue  [{'email': 'nhoebel@kmotifs.com'}]
#
# ==========================
#
# 9602
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '326'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Nancy J.  Hoebelheinrich', 'format': None, 'safe_value': 'Nancy J.  Hoebelheinrich'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'nhoebel@kmotifs.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '326'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Nancy J.  Hoebelheinrich', 'format': None, 'safe_value': 'Nancy J.  Hoebelheinrich'}]
# field_submission_contact_email_a : dvalue  [{'email': 'nhoebel@kmotifs.com'}]
#
# ==========================
#
# 9603
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '322'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Nancy J.  Hoebelheinrich', 'format': None, 'safe_value': 'Nancy J.  Hoebelheinrich'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'nhoebel@kmotifs.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '322'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Nancy J.  Hoebelheinrich', 'format': None, 'safe_value': 'Nancy J.  Hoebelheinrich'}]
# field_submission_contact_email_a : dvalue  [{'email': 'nhoebel@kmotifs.com'}]
#
# ==========================
#
# 9750
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9765
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9766
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9767
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9768
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9776
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9792
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9793
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9794
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9795
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9796
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9797
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9813
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9828
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9837
# {'field_lr_access_features': {'und': [{'target_id': '2268'}, {'target_id': '2269'}]}, 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Tamar Norkin', 'format': None, 'safe_value': 'Tamar Norkin'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'tnorkin@usgs.edu'}]}}
# -----------
#
# field_lr_access_features : dvalue  [{'target_id': '2268'}, {'target_id': '2269'}]
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Tamar Norkin', 'format': None, 'safe_value': 'Tamar Norkin'}]
# field_submission_contact_email_a : dvalue  [{'email': 'tnorkin@usgs.edu'}]
#
# ==========================
#
# 9840
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9841
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9842
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9843
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '218'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '218'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9847
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9861
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '231'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '231'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9865
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9866
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9867
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9868
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9869
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9870
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9871
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9872
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9873
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9885
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '234'}, {'value': '316'}, {'value': '317'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Ellen Verbakel', 'format': None, 'safe_value': 'Ellen Verbakel'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'cursus@researchdata.nl'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '234'}, {'value': '316'}, {'value': '317'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Ellen Verbakel', 'format': None, 'safe_value': 'Ellen Verbakel'}]
# field_submission_contact_email_a : dvalue  [{'email': 'cursus@researchdata.nl'}]
#
# ==========================
#
# 9886
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '235'}, {'value': '236'}, {'value': '237'}]}, 'field_lr_languages_secondary': {'und': [{'value': 'fr'}, {'value': 'pt'}, {'value': 'es'}]}, 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'abbypenn93@gmail.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '235'}, {'value': '236'}, {'value': '237'}]
# field_lr_languages_secondary : dvalue  [{'value': 'fr'}, {'value': 'pt'}, {'value': 'es'}]
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]
# field_submission_contact_email_a : dvalue  [{'email': 'abbypenn93@gmail.com'}]
#
# ==========================
#
# 9887
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '238'}, {'value': '239'}, {'value': '240'}]}, 'field_lr_languages_secondary': {'und': [{'value': 'fr'}, {'value': 'pt'}, {'value': 'es'}]}, 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'abbypenn93@gmail.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '238'}, {'value': '239'}, {'value': '240'}]
# field_lr_languages_secondary : dvalue  [{'value': 'fr'}, {'value': 'pt'}, {'value': 'es'}]
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]
# field_submission_contact_email_a : dvalue  [{'email': 'abbypenn93@gmail.com'}]
#
# ==========================
#
# 9891
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '242'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '242'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9892
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '245'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '245'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9893
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '246'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '246'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9894
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '247'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': [], 'field_submission_contact_email_a': []}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '247'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : lvalue []
# field_submission_contact_email_a : lvalue []
#
# ==========================
#
# 9901
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': [], 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Jane Wyngaard', 'format': None, 'safe_value': 'Jane Wyngaard'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'jwyngaar@nd.edu'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : lvalue []
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Jane Wyngaard', 'format': None, 'safe_value': 'Jane Wyngaard'}]
# field_submission_contact_email_a : dvalue  [{'email': 'jwyngaar@nd.edu'}]
#
# ==========================
#
# 9904
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '263'}, {'value': '264'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Andrew Goodwillie', 'format': None, 'safe_value': 'Andrew Goodwillie'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'andrewg@ldeo.columbia.edu'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '263'}, {'value': '264'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Andrew Goodwillie', 'format': None, 'safe_value': 'Andrew Goodwillie'}]
# field_submission_contact_email_a : dvalue  [{'email': 'andrewg@ldeo.columbia.edu'}]
#
# ==========================
#
# 9905
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '262'}, {'value': '266'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Andrew Goodwillie', 'format': None, 'safe_value': 'Andrew Goodwillie'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'andrewg@ldeo.columbia.edu'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '262'}, {'value': '266'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Andrew Goodwillie', 'format': None, 'safe_value': 'Andrew Goodwillie'}]
# field_submission_contact_email_a : dvalue  [{'email': 'andrewg@ldeo.columbia.edu'}]
#
# ==========================
#
# 9906
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '248'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Rowena Davis', 'format': None, 'safe_value': 'Rowena Davis'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'rowenaidavis@email.arizona.edu'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '248'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Rowena Davis', 'format': None, 'safe_value': 'Rowena Davis'}]
# field_submission_contact_email_a : dvalue  [{'email': 'rowenaidavis@email.arizona.edu'}]
#
# ==========================
#
# 9916
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '250'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'abbypenn93@gmail.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '250'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]
# field_submission_contact_email_a : dvalue  [{'email': 'abbypenn93@gmail.com'}]
#
# ==========================
#
# 9917
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '251'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'abbypenn93@gmail.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '251'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]
# field_submission_contact_email_a : dvalue  [{'email': 'abbypenn93@gmail.com'}]
#
# ==========================
#
# 9918
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '252'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'abbypenn93@gmail.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '252'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]
# field_submission_contact_email_a : dvalue  [{'email': 'abbypenn93@gmail.com'}]
#
# ==========================
#
# 9919
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '253'}, {'value': '254'}, {'value': '255'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'abbypenn93@gmail.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '253'}, {'value': '254'}, {'value': '255'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]
# field_submission_contact_email_a : dvalue  [{'email': 'abbypenn93@gmail.com'}]
#
# ==========================
#
# 9921
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '256'}, {'value': '258'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'abbypenn93@gmail.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '256'}, {'value': '258'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]
# field_submission_contact_email_a : dvalue  [{'email': 'abbypenn93@gmail.com'}]
#
# ==========================
#
# 9922
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '257'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'abbypenn93@gmail.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '257'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]
# field_submission_contact_email_a : dvalue  [{'email': 'abbypenn93@gmail.com'}]
#
# ==========================
#
# 9923
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '259'}, {'value': '260'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'abbypenn93@gmail.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '259'}, {'value': '260'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]
# field_submission_contact_email_a : dvalue  [{'email': 'abbypenn93@gmail.com'}]
#
# ==========================
#
# 9927
# {'field_lr_access_features': [], 'field_lr_contributor_orgs': {'und': [{'value': '267'}, {'value': '268'}]}, 'field_lr_languages_secondary': [], 'field_lr_usage_rights': [], 'field_dmt_submitter_name': {'und': [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]}, 'field_submission_contact_email_a': {'und': [{'email': 'abbypenn93@gmail.com'}]}}
# -----------
#
# field_lr_access_features : lvalue []
# field_lr_contributor_orgs : dvalue  [{'value': '267'}, {'value': '268'}]
# field_lr_languages_secondary : lvalue []
# field_lr_usage_rights : lvalue []
# field_dmt_submitter_name : dvalue  [{'value': 'Abby Pennington', 'format': None, 'safe_value': 'Abby Pennington'}]
# field_submission_contact_email_a : dvalue  [{'email': 'abbypenn93@gmail.com'}]
#
# ==========================
#
# 9928
# ...
#
# field-name-field-lr-author-people :  ['Karl Benedict']
#
# field-name-field-lr-license :  ['Apache-2.0']
#
# field-name-field-lr-usage-rights :  None
#
# field-name-field-lr-payment-required :  ['No fee']
#
# field-name-field-lr-citation :  None
#
# field-name-field-lr-language-primary :  ['English']
#
# field-name-field-lr-languages-secondary :  None
#
# field-name-field-lr-keywords :  ['Data coding', 'Data handling', 'Electronic lab notebook (ELN)', 'Programming', 'Python']
#
# field-name-field-lr-subject :  None
#
# field-name-field-lr-date-published :  ['2017-09-07T00:00:00-05:00', '2017-09-07T00:00:00-05:00']
#
# field-name-field-lr-locator-id :  None
#
# field-name-field-lr-locator-type :  None
#
# field-name-field-lr-publisher :  ['University of New Mexico Research Data Services']
#
# field-name-field-lr-version :  None
#
# field-name-field-lr-media-type :  ['Interactive Resource - requires a user to take action or make a request in order for the content to be understood, executed or experienced.']
#
# field-name-field-lr-contributor-people :  None
#
# field-name-field-lr-contributor-orgs :  None
#
# field-name-field-lr-contact-people :  ['Karl Benedict']
#
# field-name-field-lr-contact-organizations :  ['University of New Mexico Research Data Services']
#
# field-name-field-lr-ed-purpose :  ['Instruction - detailed information about aspects or processes related to data management.']
#
# field-name-field-lr-type :  ['Learning Activity - guided or unguided activity engaged in by a learner to acquire skills, concepts, or knowledge that may or may not be defined by a lesson.  Examples:  data exercises, data recipes.']
#
# field-name-field-lr-ed-audience :  ['Citizen scientist', 'Graduate student', 'High school student', 'Librarian', 'Undergraduate student']
#
# field-name-field-lr-completion-time :  ['More than 1 hour (but less than 1 day)']
#
# field-name-field-lr-ed-framework :  None
#
# field-name-field-lr-ed-framework-node-esip :  None
#
# field-name-field-lr-ed-framework-node-usgs :  None
#
# field-name-field-lr-ed-framework-node-data1 :  None
#
# field-name-field-lr-framework-node-fair :  None
#
# field-name-field-dmt-submitter-name :  None
#
# field-name-field-submission-contact-email-a :  None
#
# field-name-field-lr-access-features :  None
#
# ======================
# processing:  http://dmtclearinghouse.esipfed.org/node/9552
# field-name-title :  ['Mozilla Science Lab Open Data Instructor Guides']
#
# field-name-field-lr-url :  ['https://mozillascience.github.io/open-data-guides/']
#
# field-name-field-lr-abstract :  ["This site is a resource for train-the-trainer type materials on Open Data. It's meant to provide a series of approachable, fun, collaborative workshops where each of the modules is interactive and customizable to meet a variety of audiences.\n"]
#
# field-name-field-lr-author-people :  ['Zannah Marsh']
#
# field-name-field-lr-license :  None
#
# field-name-field-lr-usage-rights :  None
#
# field-name-field-lr-payment-required :  ['No fee']
#
# field-name-field-lr-citation :  None
#
# field-name-field-lr-language-primary :  ['English']
#
# field-name-field-lr-languages-secondary :  None
#
# field-name-field-lr-keywords :  ['Accessible data - FAIR Data Principle', 'Data policy', 'Data sharing', 'Data stewardship', 'Findable data - FAIR Data Principle', 'Open data', 'Open science']
#
# field-name-field-lr-subject :  None
#
# field-name-field-lr-date-published :  []
#
# field-name-field-lr-locator-id :  None
#
# field-name-field-lr-locator-type :  None
#
# field-name-field-lr-publisher :  ['Mozilla Science Lab']
#
# field-name-field-lr-version :  None
#
# field-name-field-lr-media-type :  ['Collection - a group or set of items that comprise a single learning resource, e.g., a PDF version of a slide presentation, an audio file of the presentation and a textual representation of the oral transcription of the presentation.']
#
# field-name-field-lr-contributor-people :  None
#
# field-name-field-lr-contributor-orgs :  None
#
# field-name-field-lr-contact-people :  ['Stephanie Wright']
#
# field-name-field-lr-contact-organizations :  ['Mozilla Science Lab']
#
# field-name-field-lr-ed-purpose :  ['Instruction - detailed information about aspects or processes related to data management.']
#
# field-name-field-lr-type :  ['Educator Curriculum Guide - document that defines what concepts should be taught and/or how a concept should be taught effectively.']
#
# field-name-field-lr-ed-audience :  ['Data manager', 'Data policymaker', 'Data professional', 'Early-career research scientist', 'Educator', 'Graduate student', 'High school student', 'Librarian', 'Undergraduate student']
#
# field-name-field-lr-completion-time :  ['More than 1 hour (but less than 1 day)']
#
# field-name-field-lr-ed-framework :  None
#
# field-name-field-lr-ed-framework-node-esip :  None
#
# field-name-field-lr-ed-framework-node-usgs :  None
#
# field-name-field-lr-ed-framework-node-data1 :  None
#
# field-name-field-lr-framework-node-fair :  None
#
# field-name-field-dmt-submitter-name :  None
#
# field-name-field-submission-contact-email-a :  None
#
# field-name-field-lr-access-features :  None
#
# ======================
# processing:  http://dmtclearinghouse.esipfed.org/node/10237
#
# field-name-title :  ['Data Management: Using Metadata to Find, Interpret & Share Your Data']
#
# field-name-field-lr-url :  ['https://www.dropbox.com/s/picfvulkyrbbi6d/Metadata_Slides_MIT.pdf?dl=0']
#
# field-name-field-lr-abstract :  ['Ever struggle to find that file you tucked away last semester (or last week)? Having trouble remembering details in order to re-use your own data? Need others to understand & use your data? This workshop will introduce you to the power of\xa0metadata: what it is, why it’s so important, and how to get started with it. Stop wasting time in finding, interpreting or sharing your data. Whether you are new to thinking about metadata or you’re looking to build off some basic knowledge, this workshop is for you!\n']
#
# field-name-field-lr-author-people :  ['Christine   Malinowski']
#
# field-name-field-lr-license :  ['Creative Commons Attribution 4.0 International - CC BY 4.0']
#
# field-name-field-lr-usage-rights :  None
#
# field-name-field-lr-payment-required :  ['No fee']
#
# field-name-field-lr-citation :  None
#
# field-name-field-lr-language-primary :  ['English']
#
# field-name-field-lr-languages-secondary :  None
#
# field-name-field-lr-keywords :  ['Data sharing', 'Metadata']
#
# field-name-field-lr-subject :  None
#
# field-name-field-lr-date-published :  ['2015-01-01T00:00:00-06:00', '2015-01-01T00:00:00-06:00']
#
# field-name-field-lr-locator-id :  None
#
# field-name-field-lr-locator-type :  None
#
# field-name-field-lr-publisher :  ['Massachusetts Institute of Technology (MIT) Libraries']
#
# field-name-field-lr-version :  None
#
# field-name-field-lr-media-type :  ['Presentation - representation of the particular way in which an author shows, describes or explains one or more concepts, e.g., a set of Powerpoint slides.']
#
# field-name-field-lr-contributor-people :  None
#
# field-name-field-lr-contributor-orgs :  None
#
# field-name-field-lr-contact-people :  ['Christine   Malinowski']
#
# field-name-field-lr-contact-organizations :  ['MIT Libraries Data Management Services']
#
# field-name-field-lr-ed-purpose :  ['Instruction - detailed information about aspects or processes related to data management.']
#
# field-name-field-lr-type :  ['Lesson - detailed description of an element of instruction in a course, [could be] contained in a unit of one or more lessons, and used by a teacher to guide class instruction.  Example: presentation slides on a topic.']
#
# field-name-field-lr-ed-audience :  ['Citizen scientist', 'Graduate student', 'High school student', 'Undergraduate student']
#
# field-name-field-lr-completion-time :  ['Up to 1 hour']
#
# field-name-field-lr-ed-framework :  None
#
# field-name-field-lr-ed-framework-node-esip :  None
#
# field-name-field-lr-ed-framework-node-usgs :  None
#
# field-name-field-lr-ed-framework-node-data1 :  None
#
# field-name-field-lr-framework-node-fair :  None
#
# field-name-field-dmt-submitter-name :  None
#
# field-name-field-submission-contact-email-a :  None
#
# field-name-field-lr-access-features :  None
#
# ======================
# processing:  http://dmtclearinghouse.esipfed.org/node/10235
#
# field-name-title :  ['Data Management: Strategies for Data Sharing and Storage']
#
# field-name-field-lr-url :  ['https://www.dropbox.com/s/a9tux3yvr46oryp/DataSharingStorage_Slides_MIT.pdf?dl=0']
#
# field-name-field-lr-abstract :  ['Not sure how to publish and share your data? Unclear on the best formats and information to include for optimal data reuse? This workshop will review existing options for long-term storage and strategies for sharing data with other researchers. Topics will include: data publication and citation, persistent identifiers, versioning, data formats and metadata for reuse, repositories, cost models and management strategies.\n']
#
# field-name-field-lr-author-people :  ['Christine   Malinowski', 'Amy   Nurnberger']
#
# field-name-field-lr-license :  ['Creative Commons Attribution 4.0 International - CC BY 4.0']
#
# field-name-field-lr-usage-rights :  None
#
# field-name-field-lr-payment-required :  ['No fee']
#
# field-name-field-lr-citation :  None
#
# field-name-field-lr-language-primary :  ['English']
#
# field-name-field-lr-languages-secondary :  None
#
# field-name-field-lr-keywords :  ['Data citation', 'Data formats', 'Data publication', 'Data reuse - Core Trustworthy Data Repositories Requirements', 'Data sharing', 'Data storage', 'Metadata', 'Persistent Identifiers (PID)', 'Version control']
#
# field-name-field-lr-subject :  None
#
# field-name-field-lr-date-published :  ['2018-01-17T00:00:00-06:00', '2018-01-17T00:00:00-06:00']
#
# field-name-field-lr-locator-id :  None
#
# field-name-field-lr-locator-type :  None
#
# field-name-field-lr-publisher :  ['MIT Libraries Data Management Services']
#
# field-name-field-lr-version :  None
#
# field-name-field-lr-media-type :  ['Presentation - representation of the particular way in which an author shows, describes or explains one or more concepts, e.g., a set of Powerpoint slides.']
#
# field-name-field-lr-contributor-people :  None
#
# field-name-field-lr-contributor-orgs :  None
#
# field-name-field-lr-contact-people :  ['Amy   Nurnberger', 'Christine   Malinowski']
#
# field-name-field-lr-contact-organizations :  ['MIT Libraries Data Management Services']
#
# field-name-field-lr-ed-purpose :  ['Instruction - detailed information about aspects or processes related to data management.']
#
# field-name-field-lr-type :  ['Lesson - detailed description of an element of instruction in a course, [could be] contained in a unit of one or more lessons, and used by a teacher to guide class instruction.  Example: presentation slides on a topic.']
#
# field-name-field-lr-ed-audience :  ['Citizen scientist', 'Educator', 'Graduate student', 'High school student', 'Librarian', 'Undergraduate student']
#
# field-name-field-lr-completion-time :  ['Up to 1 hour']
#
# field-name-field-lr-ed-framework :  None
#
# field-name-field-lr-ed-framework-node-esip :  None
#
# field-name-field-lr-ed-framework-node-usgs :  None
#
# field-name-field-lr-ed-framework-node-data1 :  None
#
# field-name-field-lr-framework-node-fair :  None
#
# field-name-field-dmt-submitter-name :  None
#
# field-name-field-submission-contact-email-a :  None
#
# field-name-field-lr-access-features :  None
#
# ======================
# processing:  http://dmtclearinghouse.esipfed.org/node/10229
# field-name-title :  ['Learning programming on Khan Academy']
#
# field-name-field-lr-url :  ['https://www.khanacademy.org/computing/computer-programming/programming/intro-to-...']
#
# field-name-field-lr-abstract :  ['In this course, we\'ll be teaching\xa0the concepts of the\xa0JavaScript\xa0programming language and the cool functions you can use with it in the\xa0ProcessingJSlibrary.\xa0Before you dig in, here\'s a brief tour of how we teach programming here on\xa0Khan Academy, and how we think you can learn the most.\nNormally, we teach on Khan Academy using videos, but here in programming land, we teach with something we call\xa0"talk-throughs". A talk-through is\xa0like a video, but it\'s actually interactive- you can pause at any time if you want to play with the code yourself, and you can spin-off if you want to make your own version of what we made. \xa0An animated GIF of a talk-through is included.\nSee Terms of Service at:\xa0\xa0https://www.khanacademy.org/about/tos\xa0\n']
#
# field-name-field-lr-author-people :  None
#
# field-name-field-lr-license :  ['MIT License']
#
# field-name-field-lr-usage-rights :  ['Khan Academy Terms of Service']
#
# field-name-field-lr-payment-required :  ['No fee']
#
# field-name-field-lr-citation :  None
#
# field-name-field-lr-language-primary :  ['English']
#
# field-name-field-lr-languages-secondary :  None
#
# field-name-field-lr-keywords :  ['Data coding', 'JavaScript', 'Programming']
#
# field-name-field-lr-subject :  None
#
# field-name-field-lr-date-published :  []
#
# field-name-field-lr-locator-id :  None
#
# field-name-field-lr-locator-type :  None
#
# field-name-field-lr-publisher :  ['Khan Academy']
#
# field-name-field-lr-version :  None
#
# field-name-field-lr-media-type :  ['Interactive Resource - requires a user to take action or make a request in order for the content to be understood, executed or experienced.']
#
# field-name-field-lr-contributor-people :  None
#
# field-name-field-lr-contributor-orgs :  None
#
# field-name-field-lr-contact-people :  None
#
# field-name-field-lr-contact-organizations :  ['Khan Academy']
#
# field-name-field-lr-ed-purpose :  ['Instruction - detailed information about aspects or processes related to data management.']
#
# field-name-field-lr-type :  ['Learning Activity - guided or unguided activity engaged in by a learner to acquire skills, concepts, or knowledge that may or may not be defined by a lesson.  Examples:  data exercises, data recipes.']
#
# field-name-field-lr-ed-audience :  ['Citizen scientist', 'Graduate student', 'High school student', 'Middle school student', 'Undergraduate student']
#
# field-name-field-lr-completion-time :  ['More than 1 hour (but less than 1 day)']
#
# field-name-field-lr-ed-framework :  None
#
# field-name-field-lr-ed-framework-node-esip :  None
#
# field-name-field-lr-ed-framework-node-usgs :  None
#
# field-name-field-lr-ed-framework-node-data1 :  None
#
# field-name-field-lr-framework-node-fair :  None
#
# field-name-field-dmt-submitter-name :  None
#
# field-name-field-submission-contact-email-a :  None
#
# field-name-field-lr-access-features :  None
#
# ======================
